# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in Dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss Dask vs. Pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance, and the data, along with its description, is available via [Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset).
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# <div>
# <image src="./images/02_medallion_architecture.png" height=300>
# </div>
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class to control the process of obtaining and transforming our data.
#
# <div>
# <image src="./images/02_target_pipeline_manager.png" height=250>
# </div>

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account. Alternatively, download the file from [this location](https://drive.google.com/drive/folders/1AA4gapDLpI194TGce1bY25sd91Km-tU3?usp=drive_link).
#
# + Extract stock prices (not ETFs) into the directory: `./05_src/data/prices_csv/`.
# + To be clear, your folder structure should include the path `05_src/data/prices_csv/stocks`.

# %% [markdown]
# The command `%run update_path.py` runs a local script that adds the repository's `./05_src/` directory to the Notebook's kernel path. This way, we can use our modules within the notebook.

# %%
# %run update_path.py

# %% [markdown]
# To load the historical price data for stocks and ETFs, use the code below. Notice the following:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager. Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by [Python's documentation](https://docs.python.org/2/howto/logging.html#logging-advanced-tutorial).

# %%
from glob import glob
import os
import pandas as pd
import random

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# + The [`glob` module](https://docs.python.org/3/library/glob.html) is used for finding path names that match specified patterns using Unix shell-style rules.
#
# + Notice that the module `glob` contains a function called `glob`; therefore, we used `from glob import glob` above.
#
# + The path in which we are searching for our csv files is produced by joining two strings:
#
#
#
#     - The value of the environment variable 'SRC_DIR' that we obtain with `os.getenv('SRC_DIR')` (this variable points to ./05_src).
#
#     - Another string given by "data/prices_csv/stocks/*.csv".
#
#     - Both strings are combined into an OS-consistent path using `os.path.join(...)`.
#
# + After we know the location of all our files, we sample a subset of them.

# %%
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))
_logs.info(f'Found {len(stock_files)} stock price files.')

random.seed(42)
n_sample = 60
stock_files = random.sample(stock_files, n_sample)
_logs.info(f'Sampled {n_sample} stock price files for processing. The files are: {stock_files   }')
# Out:
# 2026-01-19 12:57:16,860, 3619788285.py, 2, INFO, Found 5884 stock price files.
# 2026-01-19 12:57:16,861, 3619788285.py, 7, INFO, Sampled 60 stock price files for processing. The files are: ['../../05_src/data/prices_csv/stocks/HCM.csv', '../../05_src/data/prices_csv/stocks/ATHM.csv', '../../05_src/data/prices_csv/stocks/RILYP.csv', '../../05_src/data/prices_csv/stocks/ALDX.csv', '../../05_src/data/prices_csv/stocks/JHG.csv', '../../05_src/data/prices_csv/stocks/CHRS.csv', '../../05_src/data/prices_csv/stocks/BKTI.csv', '../../05_src/data/prices_csv/stocks/REFR.csv', '../../05_src/data/prices_csv/stocks/KEN.csv', '../../05_src/data/prices_csv/stocks/MDRRP.csv', '../../05_src/data/prices_csv/stocks/GRF.csv', '../../05_src/data/prices_csv/stocks/KRC.csv', '../../05_src/data/prices_csv/stocks/MICT.csv', '../../05_src/data/prices_csv/stocks/AMPY.csv', '../../05_src/data/prices_csv/stocks/A.csv', '../../05_src/data/prices_csv/stocks/WRLSU.csv', '../../05_src/data/prices_csv/stocks/PNR.csv', '../../05_src/data/prices_csv/stocks/TERP.csv', '../../05_src/data/prices_csv/stocks/TMSR.csv', '../../05_src/data/prices_csv/stocks/TDJ.csv', '../../05_src/data/prices_csv/stocks/CIK.csv', '../../05_src/data/prices_csv/stocks/SMBC.csv', '../../05_src/data/prices_csv/stocks/CNSP.csv', '../../05_src/data/prices_csv/stocks/BLK.csv', '../../05_src/data/prices_csv/stocks/CLNC.csv', '../../05_src/data/prices_csv/stocks/AOSL.csv', '../../05_src/data/prices_csv/stocks/LYV.csv', '../../05_src/data/prices_csv/stocks/IX.csv', '../../05_src/data/prices_csv/stocks/AWRE.csv', '../../05_src/data/prices_csv/stocks/KNX.csv', '../../05_src/data/prices_csv/stocks/TRXC.csv', '../../05_src/data/prices_csv/stocks/CVCY.csv', '../../05_src/data/prices_csv/stocks/UVE.csv', '../../05_src/data/prices_csv/stocks/HCKT.csv', '../../05_src/data/prices_csv/stocks/TFSL.csv', '../../05_src/data/prices_csv/stocks/ACB.csv', '../../05_src/data/prices_csv/stocks/AXP.csv', '../../05_src/data/prices_csv/stocks/GLG.csv', '../../05_src/data/prices_csv/stocks/MFO.csv', '../../05_src/data/prices_csv/stocks/PCB.csv', '../../05_src/data/prices_csv/stocks/IPDN.csv', '../../05_src/data/prices_csv/stocks/DTW.csv', '../../05_src/data/prices_csv/stocks/IQV.csv', '../../05_src/data/prices_csv/stocks/EVRI.csv', '../../05_src/data/prices_csv/stocks/LIVE.csv', '../../05_src/data/prices_csv/stocks/KZR.csv', '../../05_src/data/prices_csv/stocks/SO.csv', '../../05_src/data/prices_csv/stocks/INFY.csv', '../../05_src/data/prices_csv/stocks/BSE.csv', '../../05_src/data/prices_csv/stocks/PSN.csv', '../../05_src/data/prices_csv/stocks/TNAV.csv', '../../05_src/data/prices_csv/stocks/APTX.csv', '../../05_src/data/prices_csv/stocks/LAZY.csv', '../../05_src/data/prices_csv/stocks/DK.csv', '../../05_src/data/prices_csv/stocks/ZEUS.csv', '../../05_src/data/prices_csv/stocks/IRBT.csv', '../../05_src/data/prices_csv/stocks/AMAT.csv', '../../05_src/data/prices_csv/stocks/PSB.csv', '../../05_src/data/prices_csv/stocks/CTSO.csv', '../../05_src/data/prices_csv/stocks/UEC.csv']

# %% [markdown]
# We load the sampled files into dataframes and concatenate them:
#
# + Start with an empty list.
# + Read each file into a dataframe and [`append()` it to the list](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists). Notice that `append()` is an in-place operation (it does not return a list, it modifies the list in place).
# + Finally, we concatenate all dataframes along the vertical axis (`axis=0`) using [`pd.concat()`](https://pandas.pydata.org/docs/user_guide/merging.html#concat).
# + Notice that we do not concatenate each time that we load a dataframe. According to [Panda's documentation](https://pandas.pydata.org/docs/user_guide/merging.html#concat):
#
# > "`concat()` makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`."

# %%
dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2026-01-19 12:57:21,668, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HCM.csv
# 2026-01-19 12:57:21,695, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ATHM.csv
# 2026-01-19 12:57:21,700, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RILYP.csv
# 2026-01-19 12:57:21,703, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ALDX.csv
# 2026-01-19 12:57:21,706, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/JHG.csv
# 2026-01-19 12:57:21,709, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CHRS.csv
# 2026-01-19 12:57:21,714, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BKTI.csv
# 2026-01-19 12:57:21,726, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/REFR.csv
# 2026-01-19 12:57:21,736, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KEN.csv
# 2026-01-19 12:57:21,739, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MDRRP.csv
# 2026-01-19 12:57:21,741, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GRF.csv
# 2026-01-19 12:57:21,746, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KRC.csv
# 2026-01-19 12:57:21,753, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MICT.csv
# 2026-01-19 12:57:21,757, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMPY.csv
# 2026-01-19 12:57:21,760, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/A.csv
# 2026-01-19 12:57:21,766, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WRLSU.csv
# 2026-01-19 12:57:21,769, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PNR.csv
# 2026-01-19 12:57:21,783, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TERP.csv
# 2026-01-19 12:57:21,786, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TMSR.csv
# 2026-01-19 12:57:21,789, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TDJ.csv
# 2026-01-19 12:57:21,793, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CIK.csv
# 2026-01-19 12:57:21,801, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SMBC.csv
# 2026-01-19 12:57:21,808, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CNSP.csv
# 2026-01-19 12:57:21,810, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BLK.csv
# 2026-01-19 12:57:21,816, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CLNC.csv
# 2026-01-19 12:57:21,819, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AOSL.csv
# 2026-01-19 12:57:21,823, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LYV.csv
# 2026-01-19 12:57:21,828, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IX.csv
# 2026-01-19 12:57:21,835, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AWRE.csv
# 2026-01-19 12:57:21,842, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KNX.csv
# 2026-01-19 12:57:21,851, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TRXC.csv
# 2026-01-19 12:57:21,858, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CVCY.csv
# 2026-01-19 12:57:21,865, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UVE.csv
# 2026-01-19 12:57:21,873, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HCKT.csv
# 2026-01-19 12:57:21,879, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TFSL.csv
# 2026-01-19 12:57:21,884, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ACB.csv
# 2026-01-19 12:57:21,892, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AXP.csv
# 2026-01-19 12:57:21,904, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GLG.csv
# 2026-01-19 12:57:21,908, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MFO.csv
# 2026-01-19 12:57:21,913, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PCB.csv
# 2026-01-19 12:57:21,916, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IPDN.csv
# 2026-01-19 12:57:21,920, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DTW.csv
# 2026-01-19 12:57:21,924, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IQV.csv
# 2026-01-19 12:57:21,928, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/EVRI.csv
# 2026-01-19 12:57:21,934, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LIVE.csv
# 2026-01-19 12:57:21,941, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KZR.csv
# 2026-01-19 12:57:21,944, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SO.csv
# 2026-01-19 12:57:21,957, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/INFY.csv
# 2026-01-19 12:57:21,965, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BSE.csv
# 2026-01-19 12:57:21,972, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PSN.csv
# 2026-01-19 12:57:21,975, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TNAV.csv
# 2026-01-19 12:57:21,979, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/APTX.csv
# 2026-01-19 12:57:21,982, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LAZY.csv
# 2026-01-19 12:57:21,984, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DK.csv
# 2026-01-19 12:57:21,989, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ZEUS.csv
# 2026-01-19 12:57:21,997, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IRBT.csv
# 2026-01-19 12:57:22,002, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMAT.csv
# 2026-01-19 12:57:22,012, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PSB.csv
# 2026-01-19 12:57:22,020, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CTSO.csv
# 2026-01-19 12:57:22,025, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UEC.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data using the [`info()` dataframe method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html):

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230273 entries, 0 to 230272
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       230273 non-null  datetime64[ns]
#  1   Open       230260 non-null  float64
#  2   High       230260 non-null  float64
#  3   Low        230260 non-null  float64
#  4   Close      230260 non-null  float64
#  5   Adj Close  230260 non-null  float64
#  6   Volume     230260 non-null  float64
#  7   source     230273 non-null  object
#  8   ticker     230273 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 15.8+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. Good references for this type of data manipulation are:
#
# + [Panda's Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data).
# + [Panda's Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['HCM',
#  'ATHM',
#  'RILYP',
#  'ALDX',
#  'JHG',
#  'CHRS',
#  'BKTI',
#  'REFR',
#  'KEN',
#  'MDRRP',
#  'GRF',
#  'KRC',
#  'MICT',
#  'AMPY',
#  'A',
#  'WRLSU',
#  'PNR',
#  'TERP',
#  'TMSR',
#  'TDJ',
#  'CIK',
#  'SMBC',
#  'CNSP',
#  'BLK',
#  'CLNC',
#  'AOSL',
#  'LYV',
#  'IX',
#  'AWRE',
#  'KNX',
#  'TRXC',
#  'CVCY',
#  'UVE',
#  'HCKT',
#  'TFSL',
#  'ACB',
#  'AXP',
#  'GLG',
#  'MFO',
#  'PCB',
#  'IPDN',
#  'DTW',
#  'IQV',
#  'EVRI',
#  'LIVE',
#  'KZR',
#  'SO',
#  'INFY',
#  'BSE',
#  'PSN',
#  'TNAV',
#  'APTX',
#  'LAZY',
#  'DK',
#  'ZEUS',
#  'IRBT',
#  'AMAT',
#  'PSB',
#  'CTSO',
#  'UEC']

# %% [markdown]
# # Storing Data in CSV
#
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parquet, by measuring their performance:
#
#     - Time to save: We will measure time by using the `time` library.
#     - Space required on drive: We will use the custom function below.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %% [markdown]
# Load the specification of a temporary directory from the environment  and create a subdirectory in it called "csv":
#
# + Use `os.getenv("TEMP_DATA")` to obtain the desired location of the temporary folder from an environment variable.
# + If the subdirectory exists, delete it using `shutil.rmtree()`; the flag `ignore_errors=True` helps us in case the subdirectory does not exist (for instance, in the first run).
# + Create a directory with path given by `csv_dir` using `os.makedirs()`; the flag `exist_ok=True` indicates that if the directory already exists, then the function will do nothing.
# + Finally, create the stock price file location, `stock_csv`, which will be used to create the csv file.

# %%
import shutil

temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")

shutil.rmtree(csv_dir, ignore_errors=True)
os.makedirs(csv_dir, exist_ok=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")

# %% [markdown]
# Save the concatenated dataframe to a CSV file. We measure the time elapsed by storing the start and end times, then we calculate their difference in seconds.

# %%
import time

start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2026-01-19 12:57:40,277, 807204384.py, 7, INFO, Writing data ((230273, 9)) to csv took 0.9443402290344238 seconds.
# 2026-01-19 12:57:40,278, 807204384.py, 8, INFO, CSV file size 25.988193 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Notes on Dask
#
# We could use Pandas to save the data directly into Parquet files. However, we will use a different approach by applying the [Dask framework](https://www.dask.org/). Dask provides functionality for working with datasets that do not fit in memory and parallelization to speed up computation. A few notes on Dask and Pandas:
#
# - Pandas, Parquet, and Arrow:
#
#     + We can work with large datasets and Parquet files in Pandas, but we will generally be limited by the amount of data that can fit in our computer's memory.
#     + Pandas can write Parquet files using a PyArrow backend. In fact, recent versions of Pandas support PyArrow data types, and future versions will require a PyArrow backend.
#     + The PyArrow library is an interface between Python and the Apache Arrow project. In particular, the [Parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are Apache projects.
#
# - Dask
#
#     + Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on Pandas-like dataframes.
#     + Dask is also relatively easy to use as it mimics Pandas' API.
#     + Dask allows us to work with larger datasets than Pandas. In a sense, it is an intermediate step between Pandas and big-data frameworks like Spark (or Databricks).
#     + If you are familiar with Pandas, a good introduction is [10 Minutes to Dask](https://docs.dask.org/en/stable/10-minutes-to-dask.html).

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2026-01-19 13:02:20,824, 817812245.py, 7, INFO, Writing dd ((230273, 9)) to parquet took 0.22370004653930664 seconds.
# 2026-01-19 13:02:20,825, 817812245.py, 8, INFO, Parquet file size 8.889431 MB

# %% [markdown]
# ### Pandas, Dask, and Parquet
#
# The distinction of Pandas Dataframes, Dask Dataframes, and Parquet files is important:
#
# + Pandas dataframes combine the functionality of [NumPy](https://numpy.org/) (efficient vector operations, especially vector algebra) with a concise data manipulation framework that allows us to create columns of different data types (NumPy only allows single-type matrices), database-like operations (such as filtering rows, subsetting columns, and joining different dataframes).
# + Dask dataframes extend the functionality of Pandas dataframes beyond the confines of available memory and implement parallelized operations, among other benefits.
# + Parquet files are a file format. Parquet files can be created by Pandas and Dask, but Dask offers a superior interface. Parquet files are immutable: once written, they cannot be modified.
# + Parquet and Dask are not the same: Parquet is a file format that can be accessed by many applications and programming languages (Python, R, Power BI, etc.), while Dask is a Python package for working with large datasets using distributed computation.

# %% [markdown]
# ### Dask is Powerful, but not Infallible
#
# It is tempting to think of Dask as a super-Pandas, but each package has its advantages and disadvantages.
#
# + Dask is not good at everything (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
# + A useful and somewhat idiosyncratic comparison of various data manipulation frameworks is shown below (from [DataFrames at Scale Comparison: TPC-H](https://docs.coiled.io/blog/tpch.html#when-to-use-duckdb-vs-polars-vs-dask-vs-spark))
#
# Concept              | Spark | Dask | DuckDB | Polars
# ---------------------|-------|------|--------|--------
# Fast Locally         | ❌    | 🤔  | ✅     | ✅
# Fast on Cloud (1 TB) | ✅    | ✅  | ✅     | ❌
# Fast on Cloud (10 TB)| ❌    | ✅  | ✅     | ❌
# Scales Out           | ✅    | ✅  | ❌     | ❌
# SQL                  | ✅    | 🤔  | ✅     | 🤔
# More than SQL        | ✅    | ✅  | ❌     | ✅
# Sensible Defaults    | ❌    | ✅  | ✅     | ✅
#
#
# ### Dask Best Practices
#
# Parallelism brings extra complexity and overhead. Here are a few ideas to help you decide when to use Dask (from [Dask's Best Practices](https://docs.dask.org/en/stable/best-practices.html)):
#
# #### Small is Better
#
# + Start small: if possible, use Pandas. Also, try to reduce your data using aggregation, then use Pandas.
# + More generally, NumPy, Pandas, and Scikit-Learn may have faster functions for what you need. Consult the relevant documentation, experiment, and/or consult with a colleague or expert.
#
# #### Index with Care
#
# + Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
# + Minimize full-data shuffling as much as possible: indexing is an expensive operation.
#
# ### Consider the Cost of Joins
#
# + Consider cases such as small-to-large joins, where the small dataframe fits in memory, but the large one does not. The small dataframe can be Pandas, while the larger one is a Dask dataframe.
# + Some joins are more expensive than others.
#
#     * Not expensive:
#
#         - Join a Dask DataFrame with a Pandas DataFrame.
#         - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#         - Join Dask DataFrames along their indexes.
#
#     * Expensive:
#
#         - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How Do We Store Prices?
#
# + We can store our data as a single blob.
#
#   - This can be difficult to maintain, especially because parquet files are immutable.
#   - Using a single file, we would need to recreate the complete file any time that we update it.
#
# + An alternative strategy is to organize data files by ticker and date:
#
#   - We can create one file per ticker and month (or any other suitable frequency).
#   - Under this approach, we would only need to recreate the latest month's file at any update.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    # Filter data for ticker
    # Notice that these are Pandas dataframes
    _logs.info(f'Processing ticker: {ticker}')
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        _logs.info(f'Processing year {yr} for ticker {ticker}.')
        # Filter data for year and convert to Dask dataframe
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        
        # Define path and create directories if not exist
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        _logs.info(f'Writing data to path: {yr_path}')

        # Write to Parquet
        yr_dd.to_parquet(yr_path, engine = "pyarrow")
# Out:
# 2026-01-19 13:02:44,343, 2113979629.py, 4, INFO, Processing ticker: HCM
# 2026-01-19 13:02:44,358, 2113979629.py, 8, INFO, Processing year 2016 for ticker HCM.
# 2026-01-19 13:02:44,363, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2016
# 2026-01-19 13:02:44,372, 2113979629.py, 8, INFO, Processing year 2017 for ticker HCM.
# 2026-01-19 13:02:44,376, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2017
# 2026-01-19 13:02:44,385, 2113979629.py, 8, INFO, Processing year 2018 for ticker HCM.
# 2026-01-19 13:02:44,387, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2018
# 2026-01-19 13:02:44,395, 2113979629.py, 8, INFO, Processing year 2019 for ticker HCM.
# 2026-01-19 13:02:44,397, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2019
# 2026-01-19 13:02:44,405, 2113979629.py, 8, INFO, Processing year 2020 for ticker HCM.
# 2026-01-19 13:02:44,408, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2020
# 2026-01-19 13:02:44,416, 2113979629.py, 4, INFO, Processing ticker: ATHM
# 2026-01-19 13:02:44,425, 2113979629.py, 8, INFO, Processing year 2013 for ticker ATHM.
# 2026-01-19 13:02:44,427, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2013
# 2026-01-19 13:02:44,435, 2113979629.py, 8, INFO, Processing year 2014 for ticker ATHM.
# 2026-01-19 13:02:44,438, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2014
# 2026-01-19 13:02:44,446, 2113979629.py, 8, INFO, Processing year 2015 for ticker ATHM.
# 2026-01-19 13:02:44,449, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2015
# 2026-01-19 13:02:44,457, 2113979629.py, 8, INFO, Processing year 2016 for ticker ATHM.
# 2026-01-19 13:02:44,460, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2016
# 2026-01-19 13:02:44,468, 2113979629.py, 8, INFO, Processing year 2017 for ticker ATHM.
# 2026-01-19 13:02:44,470, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2017
# 2026-01-19 13:02:44,478, 2113979629.py, 8, INFO, Processing year 2018 for ticker ATHM.
# 2026-01-19 13:02:44,481, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2018
# 2026-01-19 13:02:44,489, 2113979629.py, 8, INFO, Processing year 2019 for ticker ATHM.
# 2026-01-19 13:02:44,491, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2019
# 2026-01-19 13:02:44,500, 2113979629.py, 8, INFO, Processing year 2020 for ticker ATHM.
# 2026-01-19 13:02:44,502, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2020
# 2026-01-19 13:02:44,510, 2113979629.py, 4, INFO, Processing ticker: RILYP
# 2026-01-19 13:02:44,519, 2113979629.py, 8, INFO, Processing year 2020 for ticker RILYP.
# 2026-01-19 13:02:44,521, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/RILYP/RILYP_2020
# 2026-01-19 13:02:44,529, 2113979629.py, 4, INFO, Processing ticker: ALDX
# 2026-01-19 13:02:44,538, 2113979629.py, 8, INFO, Processing year 2014 for ticker ALDX.
# 2026-01-19 13:02:44,541, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2014
# 2026-01-19 13:02:44,550, 2113979629.py, 8, INFO, Processing year 2015 for ticker ALDX.
# 2026-01-19 13:02:44,554, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2015
# 2026-01-19 13:02:44,562, 2113979629.py, 8, INFO, Processing year 2016 for ticker ALDX.
# 2026-01-19 13:02:44,565, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2016
# 2026-01-19 13:02:44,572, 2113979629.py, 8, INFO, Processing year 2017 for ticker ALDX.
# 2026-01-19 13:02:44,583, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2017
# 2026-01-19 13:02:44,609, 2113979629.py, 8, INFO, Processing year 2018 for ticker ALDX.
# 2026-01-19 13:02:44,611, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2018
# 2026-01-19 13:02:44,625, 2113979629.py, 8, INFO, Processing year 2019 for ticker ALDX.
# 2026-01-19 13:02:44,627, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2019
# 2026-01-19 13:02:44,635, 2113979629.py, 8, INFO, Processing year 2020 for ticker ALDX.
# 2026-01-19 13:02:44,637, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2020
# 2026-01-19 13:02:44,644, 2113979629.py, 4, INFO, Processing ticker: JHG
# 2026-01-19 13:02:44,652, 2113979629.py, 8, INFO, Processing year 2017 for ticker JHG.
# 2026-01-19 13:02:44,655, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2017
# 2026-01-19 13:02:44,663, 2113979629.py, 8, INFO, Processing year 2018 for ticker JHG.
# 2026-01-19 13:02:44,665, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2018
# 2026-01-19 13:02:44,672, 2113979629.py, 8, INFO, Processing year 2019 for ticker JHG.
# 2026-01-19 13:02:44,675, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2019
# 2026-01-19 13:02:44,682, 2113979629.py, 8, INFO, Processing year 2020 for ticker JHG.
# 2026-01-19 13:02:44,685, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2020
# 2026-01-19 13:02:44,692, 2113979629.py, 4, INFO, Processing ticker: CHRS
# 2026-01-19 13:02:44,701, 2113979629.py, 8, INFO, Processing year 2001 for ticker CHRS.
# 2026-01-19 13:02:44,703, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2001
# 2026-01-19 13:02:44,710, 2113979629.py, 8, INFO, Processing year 2002 for ticker CHRS.
# 2026-01-19 13:02:44,712, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2002
# 2026-01-19 13:02:44,719, 2113979629.py, 8, INFO, Processing year 2003 for ticker CHRS.
# 2026-01-19 13:02:44,721, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2003
# 2026-01-19 13:02:44,730, 2113979629.py, 8, INFO, Processing year 2005 for ticker CHRS.
# 2026-01-19 13:02:44,732, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2005
# 2026-01-19 13:02:44,740, 2113979629.py, 8, INFO, Processing year 2006 for ticker CHRS.
# 2026-01-19 13:02:44,742, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2006
# 2026-01-19 13:02:44,749, 2113979629.py, 8, INFO, Processing year 2007 for ticker CHRS.
# 2026-01-19 13:02:44,751, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2007
# 2026-01-19 13:02:44,759, 2113979629.py, 8, INFO, Processing year 2008 for ticker CHRS.
# 2026-01-19 13:02:44,761, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2008
# 2026-01-19 13:02:44,769, 2113979629.py, 8, INFO, Processing year 2011 for ticker CHRS.
# 2026-01-19 13:02:44,771, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2011
# 2026-01-19 13:02:44,778, 2113979629.py, 8, INFO, Processing year 2012 for ticker CHRS.
# 2026-01-19 13:02:44,780, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2012
# 2026-01-19 13:02:44,788, 2113979629.py, 8, INFO, Processing year 2013 for ticker CHRS.
# 2026-01-19 13:02:44,791, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2013
# 2026-01-19 13:02:44,799, 2113979629.py, 8, INFO, Processing year 2014 for ticker CHRS.
# 2026-01-19 13:02:44,801, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2014
# 2026-01-19 13:02:44,810, 2113979629.py, 8, INFO, Processing year 2015 for ticker CHRS.
# 2026-01-19 13:02:44,813, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2015
# 2026-01-19 13:02:44,835, 2113979629.py, 8, INFO, Processing year 2016 for ticker CHRS.
# 2026-01-19 13:02:44,839, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2016
# 2026-01-19 13:02:44,848, 2113979629.py, 8, INFO, Processing year 2017 for ticker CHRS.
# 2026-01-19 13:02:44,851, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2017
# 2026-01-19 13:02:44,866, 2113979629.py, 8, INFO, Processing year 2018 for ticker CHRS.
# 2026-01-19 13:02:44,869, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2018
# 2026-01-19 13:02:44,877, 2113979629.py, 8, INFO, Processing year 2019 for ticker CHRS.
# 2026-01-19 13:02:44,881, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2019
# 2026-01-19 13:02:44,890, 2113979629.py, 8, INFO, Processing year 2020 for ticker CHRS.
# 2026-01-19 13:02:44,893, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2020
# 2026-01-19 13:02:44,903, 2113979629.py, 4, INFO, Processing ticker: BKTI
# 2026-01-19 13:02:44,914, 2113979629.py, 8, INFO, Processing year 1980 for ticker BKTI.
# 2026-01-19 13:02:44,917, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1980
# 2026-01-19 13:02:44,927, 2113979629.py, 8, INFO, Processing year 1981 for ticker BKTI.
# 2026-01-19 13:02:44,930, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1981
# 2026-01-19 13:02:44,940, 2113979629.py, 8, INFO, Processing year 1982 for ticker BKTI.
# 2026-01-19 13:02:44,942, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1982
# 2026-01-19 13:02:44,952, 2113979629.py, 8, INFO, Processing year 1983 for ticker BKTI.
# 2026-01-19 13:02:44,955, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1983
# 2026-01-19 13:02:44,964, 2113979629.py, 8, INFO, Processing year 1984 for ticker BKTI.
# 2026-01-19 13:02:44,967, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1984
# 2026-01-19 13:02:44,976, 2113979629.py, 8, INFO, Processing year 1985 for ticker BKTI.
# 2026-01-19 13:02:44,980, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1985
# 2026-01-19 13:02:44,991, 2113979629.py, 8, INFO, Processing year 1986 for ticker BKTI.
# 2026-01-19 13:02:44,993, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1986
# 2026-01-19 13:02:45,003, 2113979629.py, 8, INFO, Processing year 1987 for ticker BKTI.
# 2026-01-19 13:02:45,007, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1987
# 2026-01-19 13:02:45,017, 2113979629.py, 8, INFO, Processing year 1988 for ticker BKTI.
# 2026-01-19 13:02:45,026, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1988
# 2026-01-19 13:02:45,035, 2113979629.py, 8, INFO, Processing year 1989 for ticker BKTI.
# 2026-01-19 13:02:45,038, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1989
# 2026-01-19 13:02:45,048, 2113979629.py, 8, INFO, Processing year 1990 for ticker BKTI.
# 2026-01-19 13:02:45,051, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1990
# 2026-01-19 13:02:45,060, 2113979629.py, 8, INFO, Processing year 1991 for ticker BKTI.
# 2026-01-19 13:02:45,062, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1991
# 2026-01-19 13:02:45,071, 2113979629.py, 8, INFO, Processing year 1992 for ticker BKTI.
# 2026-01-19 13:02:45,074, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1992
# 2026-01-19 13:02:45,084, 2113979629.py, 8, INFO, Processing year 1993 for ticker BKTI.
# 2026-01-19 13:02:45,086, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1993
# 2026-01-19 13:02:45,095, 2113979629.py, 8, INFO, Processing year 1994 for ticker BKTI.
# 2026-01-19 13:02:45,098, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1994
# 2026-01-19 13:02:45,106, 2113979629.py, 8, INFO, Processing year 1995 for ticker BKTI.
# 2026-01-19 13:02:45,109, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1995
# 2026-01-19 13:02:45,118, 2113979629.py, 8, INFO, Processing year 1996 for ticker BKTI.
# 2026-01-19 13:02:45,120, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1996
# 2026-01-19 13:02:45,128, 2113979629.py, 8, INFO, Processing year 1997 for ticker BKTI.
# 2026-01-19 13:02:45,130, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1997
# 2026-01-19 13:02:45,138, 2113979629.py, 8, INFO, Processing year 1998 for ticker BKTI.
# 2026-01-19 13:02:45,140, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1998
# 2026-01-19 13:02:45,148, 2113979629.py, 8, INFO, Processing year 1999 for ticker BKTI.
# 2026-01-19 13:02:45,150, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1999
# 2026-01-19 13:02:45,157, 2113979629.py, 8, INFO, Processing year 2000 for ticker BKTI.
# 2026-01-19 13:02:45,160, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2000
# 2026-01-19 13:02:45,168, 2113979629.py, 8, INFO, Processing year 2001 for ticker BKTI.
# 2026-01-19 13:02:45,171, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2001
# 2026-01-19 13:02:45,178, 2113979629.py, 8, INFO, Processing year 2002 for ticker BKTI.
# 2026-01-19 13:02:45,180, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2002
# 2026-01-19 13:02:45,188, 2113979629.py, 8, INFO, Processing year 2003 for ticker BKTI.
# 2026-01-19 13:02:45,190, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2003
# 2026-01-19 13:02:45,249, 2113979629.py, 8, INFO, Processing year 2004 for ticker BKTI.
# 2026-01-19 13:02:45,251, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2004
# 2026-01-19 13:02:45,258, 2113979629.py, 8, INFO, Processing year 2005 for ticker BKTI.
# 2026-01-19 13:02:45,261, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2005
# 2026-01-19 13:02:45,268, 2113979629.py, 8, INFO, Processing year 2006 for ticker BKTI.
# 2026-01-19 13:02:45,271, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2006
# 2026-01-19 13:02:45,278, 2113979629.py, 8, INFO, Processing year 2007 for ticker BKTI.
# 2026-01-19 13:02:45,280, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2007
# 2026-01-19 13:02:45,289, 2113979629.py, 8, INFO, Processing year 2008 for ticker BKTI.
# 2026-01-19 13:02:45,291, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2008
# 2026-01-19 13:02:45,300, 2113979629.py, 8, INFO, Processing year 2009 for ticker BKTI.
# 2026-01-19 13:02:45,302, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2009
# 2026-01-19 13:02:45,310, 2113979629.py, 8, INFO, Processing year 2010 for ticker BKTI.
# 2026-01-19 13:02:45,313, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2010
# 2026-01-19 13:02:45,321, 2113979629.py, 8, INFO, Processing year 2011 for ticker BKTI.
# 2026-01-19 13:02:45,323, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2011
# 2026-01-19 13:02:45,330, 2113979629.py, 8, INFO, Processing year 2012 for ticker BKTI.
# 2026-01-19 13:02:45,332, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2012
# 2026-01-19 13:02:45,339, 2113979629.py, 8, INFO, Processing year 2013 for ticker BKTI.
# 2026-01-19 13:02:45,342, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2013
# 2026-01-19 13:02:45,350, 2113979629.py, 8, INFO, Processing year 2014 for ticker BKTI.
# 2026-01-19 13:02:45,352, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2014
# 2026-01-19 13:02:45,359, 2113979629.py, 8, INFO, Processing year 2015 for ticker BKTI.
# 2026-01-19 13:02:45,361, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2015
# 2026-01-19 13:02:45,369, 2113979629.py, 8, INFO, Processing year 2016 for ticker BKTI.
# 2026-01-19 13:02:45,371, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2016
# 2026-01-19 13:02:45,381, 2113979629.py, 8, INFO, Processing year 2017 for ticker BKTI.
# 2026-01-19 13:02:45,384, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2017
# 2026-01-19 13:02:45,391, 2113979629.py, 8, INFO, Processing year 2018 for ticker BKTI.
# 2026-01-19 13:02:45,393, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2018
# 2026-01-19 13:02:45,401, 2113979629.py, 8, INFO, Processing year 2019 for ticker BKTI.
# 2026-01-19 13:02:45,403, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2019
# 2026-01-19 13:02:45,411, 2113979629.py, 8, INFO, Processing year 2020 for ticker BKTI.
# 2026-01-19 13:02:45,413, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2020
# 2026-01-19 13:02:45,421, 2113979629.py, 4, INFO, Processing ticker: REFR
# 2026-01-19 13:02:45,431, 2113979629.py, 8, INFO, Processing year 1993 for ticker REFR.
# 2026-01-19 13:02:45,433, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1993
# 2026-01-19 13:02:45,440, 2113979629.py, 8, INFO, Processing year 1994 for ticker REFR.
# 2026-01-19 13:02:45,442, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1994
# 2026-01-19 13:02:45,450, 2113979629.py, 8, INFO, Processing year 1995 for ticker REFR.
# 2026-01-19 13:02:45,452, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1995
# 2026-01-19 13:02:45,460, 2113979629.py, 8, INFO, Processing year 1996 for ticker REFR.
# 2026-01-19 13:02:45,462, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1996
# 2026-01-19 13:02:45,469, 2113979629.py, 8, INFO, Processing year 1997 for ticker REFR.
# 2026-01-19 13:02:45,471, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1997
# 2026-01-19 13:02:45,478, 2113979629.py, 8, INFO, Processing year 1998 for ticker REFR.
# 2026-01-19 13:02:45,481, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1998
# 2026-01-19 13:02:45,489, 2113979629.py, 8, INFO, Processing year 1999 for ticker REFR.
# 2026-01-19 13:02:45,492, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1999
# 2026-01-19 13:02:45,501, 2113979629.py, 8, INFO, Processing year 2000 for ticker REFR.
# 2026-01-19 13:02:45,503, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2000
# 2026-01-19 13:02:45,511, 2113979629.py, 8, INFO, Processing year 2001 for ticker REFR.
# 2026-01-19 13:02:45,513, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2001
# 2026-01-19 13:02:45,521, 2113979629.py, 8, INFO, Processing year 2002 for ticker REFR.
# 2026-01-19 13:02:45,524, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2002
# 2026-01-19 13:02:45,532, 2113979629.py, 8, INFO, Processing year 2003 for ticker REFR.
# 2026-01-19 13:02:45,534, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2003
# 2026-01-19 13:02:45,541, 2113979629.py, 8, INFO, Processing year 2004 for ticker REFR.
# 2026-01-19 13:02:45,543, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2004
# 2026-01-19 13:02:45,551, 2113979629.py, 8, INFO, Processing year 2005 for ticker REFR.
# 2026-01-19 13:02:45,553, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2005
# 2026-01-19 13:02:45,560, 2113979629.py, 8, INFO, Processing year 2006 for ticker REFR.
# 2026-01-19 13:02:45,562, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2006
# 2026-01-19 13:02:45,569, 2113979629.py, 8, INFO, Processing year 2007 for ticker REFR.
# 2026-01-19 13:02:45,572, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2007
# 2026-01-19 13:02:45,579, 2113979629.py, 8, INFO, Processing year 2008 for ticker REFR.
# 2026-01-19 13:02:45,581, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2008
# 2026-01-19 13:02:45,589, 2113979629.py, 8, INFO, Processing year 2009 for ticker REFR.
# 2026-01-19 13:02:45,591, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2009
# 2026-01-19 13:02:45,600, 2113979629.py, 8, INFO, Processing year 2010 for ticker REFR.
# 2026-01-19 13:02:45,602, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2010
# 2026-01-19 13:02:45,610, 2113979629.py, 8, INFO, Processing year 2011 for ticker REFR.
# 2026-01-19 13:02:45,612, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2011
# 2026-01-19 13:02:45,620, 2113979629.py, 8, INFO, Processing year 2012 for ticker REFR.
# 2026-01-19 13:02:45,623, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2012
# 2026-01-19 13:02:45,631, 2113979629.py, 8, INFO, Processing year 2013 for ticker REFR.
# 2026-01-19 13:02:45,633, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2013
# 2026-01-19 13:02:45,641, 2113979629.py, 8, INFO, Processing year 2014 for ticker REFR.
# 2026-01-19 13:02:45,643, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2014
# 2026-01-19 13:02:45,651, 2113979629.py, 8, INFO, Processing year 2015 for ticker REFR.
# 2026-01-19 13:02:45,653, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2015
# 2026-01-19 13:02:45,660, 2113979629.py, 8, INFO, Processing year 2016 for ticker REFR.
# 2026-01-19 13:02:45,662, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2016
# 2026-01-19 13:02:45,669, 2113979629.py, 8, INFO, Processing year 2017 for ticker REFR.
# 2026-01-19 13:02:45,671, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2017
# 2026-01-19 13:02:45,679, 2113979629.py, 8, INFO, Processing year 2018 for ticker REFR.
# 2026-01-19 13:02:45,682, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2018
# 2026-01-19 13:02:45,689, 2113979629.py, 8, INFO, Processing year 2019 for ticker REFR.
# 2026-01-19 13:02:45,692, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2019
# 2026-01-19 13:02:45,700, 2113979629.py, 8, INFO, Processing year 2020 for ticker REFR.
# 2026-01-19 13:02:45,702, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2020
# 2026-01-19 13:02:45,709, 2113979629.py, 4, INFO, Processing ticker: KEN
# 2026-01-19 13:02:45,718, 2113979629.py, 8, INFO, Processing year 2015 for ticker KEN.
# 2026-01-19 13:02:45,720, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2015
# 2026-01-19 13:02:45,727, 2113979629.py, 8, INFO, Processing year 2016 for ticker KEN.
# 2026-01-19 13:02:45,730, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2016
# 2026-01-19 13:02:45,737, 2113979629.py, 8, INFO, Processing year 2017 for ticker KEN.
# 2026-01-19 13:02:45,739, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2017
# 2026-01-19 13:02:45,747, 2113979629.py, 8, INFO, Processing year 2018 for ticker KEN.
# 2026-01-19 13:02:45,749, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2018
# 2026-01-19 13:02:45,757, 2113979629.py, 8, INFO, Processing year 2019 for ticker KEN.
# 2026-01-19 13:02:45,759, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2019
# 2026-01-19 13:02:45,767, 2113979629.py, 8, INFO, Processing year 2020 for ticker KEN.
# 2026-01-19 13:02:45,769, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2020
# 2026-01-19 13:02:45,776, 2113979629.py, 4, INFO, Processing ticker: MDRRP
# 2026-01-19 13:02:45,785, 2113979629.py, 8, INFO, Processing year 2020 for ticker MDRRP.
# 2026-01-19 13:02:45,787, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MDRRP/MDRRP_2020
# 2026-01-19 13:02:45,796, 2113979629.py, 4, INFO, Processing ticker: GRF
# 2026-01-19 13:02:45,811, 2113979629.py, 8, INFO, Processing year 2004 for ticker GRF.
# 2026-01-19 13:02:45,814, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2004
# 2026-01-19 13:02:45,822, 2113979629.py, 8, INFO, Processing year 2005 for ticker GRF.
# 2026-01-19 13:02:45,824, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2005
# 2026-01-19 13:02:45,832, 2113979629.py, 8, INFO, Processing year 2006 for ticker GRF.
# 2026-01-19 13:02:45,835, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2006
# 2026-01-19 13:02:45,843, 2113979629.py, 8, INFO, Processing year 2007 for ticker GRF.
# 2026-01-19 13:02:45,845, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2007
# 2026-01-19 13:02:45,853, 2113979629.py, 8, INFO, Processing year 2008 for ticker GRF.
# 2026-01-19 13:02:45,855, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2008
# 2026-01-19 13:02:45,862, 2113979629.py, 8, INFO, Processing year 2009 for ticker GRF.
# 2026-01-19 13:02:45,864, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2009
# 2026-01-19 13:02:45,871, 2113979629.py, 8, INFO, Processing year 2010 for ticker GRF.
# 2026-01-19 13:02:45,874, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2010
# 2026-01-19 13:02:45,881, 2113979629.py, 8, INFO, Processing year 2011 for ticker GRF.
# 2026-01-19 13:02:45,883, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2011
# 2026-01-19 13:02:45,892, 2113979629.py, 8, INFO, Processing year 2012 for ticker GRF.
# 2026-01-19 13:02:45,894, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2012
# 2026-01-19 13:02:45,901, 2113979629.py, 8, INFO, Processing year 2013 for ticker GRF.
# 2026-01-19 13:02:45,903, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2013
# 2026-01-19 13:02:45,911, 2113979629.py, 8, INFO, Processing year 2014 for ticker GRF.
# 2026-01-19 13:02:45,913, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2014
# 2026-01-19 13:02:45,920, 2113979629.py, 8, INFO, Processing year 2015 for ticker GRF.
# 2026-01-19 13:02:45,923, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2015
# 2026-01-19 13:02:45,929, 2113979629.py, 8, INFO, Processing year 2016 for ticker GRF.
# 2026-01-19 13:02:45,932, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2016
# 2026-01-19 13:02:45,939, 2113979629.py, 8, INFO, Processing year 2017 for ticker GRF.
# 2026-01-19 13:02:45,941, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2017
# 2026-01-19 13:02:45,948, 2113979629.py, 8, INFO, Processing year 2018 for ticker GRF.
# 2026-01-19 13:02:45,951, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2018
# 2026-01-19 13:02:45,958, 2113979629.py, 8, INFO, Processing year 2019 for ticker GRF.
# 2026-01-19 13:02:45,960, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2019
# 2026-01-19 13:02:45,969, 2113979629.py, 8, INFO, Processing year 2020 for ticker GRF.
# 2026-01-19 13:02:45,971, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2020
# 2026-01-19 13:02:45,978, 2113979629.py, 4, INFO, Processing ticker: KRC
# 2026-01-19 13:02:45,987, 2113979629.py, 8, INFO, Processing year 1997 for ticker KRC.
# 2026-01-19 13:02:45,990, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1997
# 2026-01-19 13:02:45,997, 2113979629.py, 8, INFO, Processing year 1998 for ticker KRC.
# 2026-01-19 13:02:46,000, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1998
# 2026-01-19 13:02:46,007, 2113979629.py, 8, INFO, Processing year 1999 for ticker KRC.
# 2026-01-19 13:02:46,010, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1999
# 2026-01-19 13:02:46,017, 2113979629.py, 8, INFO, Processing year 2000 for ticker KRC.
# 2026-01-19 13:02:46,020, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2000
# 2026-01-19 13:02:46,027, 2113979629.py, 8, INFO, Processing year 2001 for ticker KRC.
# 2026-01-19 13:02:46,030, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2001
# 2026-01-19 13:02:46,037, 2113979629.py, 8, INFO, Processing year 2002 for ticker KRC.
# 2026-01-19 13:02:46,040, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2002
# 2026-01-19 13:02:46,047, 2113979629.py, 8, INFO, Processing year 2003 for ticker KRC.
# 2026-01-19 13:02:46,050, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2003
# 2026-01-19 13:02:46,058, 2113979629.py, 8, INFO, Processing year 2004 for ticker KRC.
# 2026-01-19 13:02:46,060, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2004
# 2026-01-19 13:02:46,067, 2113979629.py, 8, INFO, Processing year 2005 for ticker KRC.
# 2026-01-19 13:02:46,069, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2005
# 2026-01-19 13:02:46,077, 2113979629.py, 8, INFO, Processing year 2006 for ticker KRC.
# 2026-01-19 13:02:46,079, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2006
# 2026-01-19 13:02:46,086, 2113979629.py, 8, INFO, Processing year 2007 for ticker KRC.
# 2026-01-19 13:02:46,089, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2007
# 2026-01-19 13:02:46,096, 2113979629.py, 8, INFO, Processing year 2008 for ticker KRC.
# 2026-01-19 13:02:46,099, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2008
# 2026-01-19 13:02:46,107, 2113979629.py, 8, INFO, Processing year 2009 for ticker KRC.
# 2026-01-19 13:02:46,110, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2009
# 2026-01-19 13:02:46,119, 2113979629.py, 8, INFO, Processing year 2010 for ticker KRC.
# 2026-01-19 13:02:46,121, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2010
# 2026-01-19 13:02:46,129, 2113979629.py, 8, INFO, Processing year 2011 for ticker KRC.
# 2026-01-19 13:02:46,131, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2011
# 2026-01-19 13:02:46,138, 2113979629.py, 8, INFO, Processing year 2012 for ticker KRC.
# 2026-01-19 13:02:46,141, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2012
# 2026-01-19 13:02:46,149, 2113979629.py, 8, INFO, Processing year 2013 for ticker KRC.
# 2026-01-19 13:02:46,151, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2013
# 2026-01-19 13:02:46,159, 2113979629.py, 8, INFO, Processing year 2014 for ticker KRC.
# 2026-01-19 13:02:46,161, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2014
# 2026-01-19 13:02:46,168, 2113979629.py, 8, INFO, Processing year 2015 for ticker KRC.
# 2026-01-19 13:02:46,170, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2015
# 2026-01-19 13:02:46,177, 2113979629.py, 8, INFO, Processing year 2016 for ticker KRC.
# 2026-01-19 13:02:46,179, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2016
# 2026-01-19 13:02:46,186, 2113979629.py, 8, INFO, Processing year 2017 for ticker KRC.
# 2026-01-19 13:02:46,189, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2017
# 2026-01-19 13:02:46,196, 2113979629.py, 8, INFO, Processing year 2018 for ticker KRC.
# 2026-01-19 13:02:46,199, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2018
# 2026-01-19 13:02:46,207, 2113979629.py, 8, INFO, Processing year 2019 for ticker KRC.
# 2026-01-19 13:02:46,209, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2019
# 2026-01-19 13:02:46,217, 2113979629.py, 8, INFO, Processing year 2020 for ticker KRC.
# 2026-01-19 13:02:46,219, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2020
# 2026-01-19 13:02:46,226, 2113979629.py, 4, INFO, Processing ticker: MICT
# 2026-01-19 13:02:46,235, 2113979629.py, 8, INFO, Processing year 2012 for ticker MICT.
# 2026-01-19 13:02:46,237, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2012
# 2026-01-19 13:02:46,244, 2113979629.py, 8, INFO, Processing year 2013 for ticker MICT.
# 2026-01-19 13:02:46,246, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2013
# 2026-01-19 13:02:46,254, 2113979629.py, 8, INFO, Processing year 2014 for ticker MICT.
# 2026-01-19 13:02:46,256, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2014
# 2026-01-19 13:02:46,264, 2113979629.py, 8, INFO, Processing year 2015 for ticker MICT.
# 2026-01-19 13:02:46,266, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2015
# 2026-01-19 13:02:46,274, 2113979629.py, 8, INFO, Processing year 2016 for ticker MICT.
# 2026-01-19 13:02:46,276, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2016
# 2026-01-19 13:02:46,283, 2113979629.py, 8, INFO, Processing year 2017 for ticker MICT.
# 2026-01-19 13:02:46,285, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2017
# 2026-01-19 13:02:46,293, 2113979629.py, 8, INFO, Processing year 2018 for ticker MICT.
# 2026-01-19 13:02:46,295, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2018
# 2026-01-19 13:02:46,302, 2113979629.py, 8, INFO, Processing year 2019 for ticker MICT.
# 2026-01-19 13:02:46,305, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2019
# 2026-01-19 13:02:46,313, 2113979629.py, 8, INFO, Processing year 2020 for ticker MICT.
# 2026-01-19 13:02:46,315, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2020
# 2026-01-19 13:02:46,323, 2113979629.py, 4, INFO, Processing ticker: AMPY
# 2026-01-19 13:02:46,332, 2113979629.py, 8, INFO, Processing year 2012 for ticker AMPY.
# 2026-01-19 13:02:46,335, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2012
# 2026-01-19 13:02:46,343, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMPY.
# 2026-01-19 13:02:46,345, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2013
# 2026-01-19 13:02:46,354, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMPY.
# 2026-01-19 13:02:46,356, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2014
# 2026-01-19 13:02:46,364, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMPY.
# 2026-01-19 13:02:46,366, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2015
# 2026-01-19 13:02:46,374, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMPY.
# 2026-01-19 13:02:46,376, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2016
# 2026-01-19 13:02:46,383, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMPY.
# 2026-01-19 13:02:46,385, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2017
# 2026-01-19 13:02:46,393, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMPY.
# 2026-01-19 13:02:46,395, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2018
# 2026-01-19 13:02:46,402, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMPY.
# 2026-01-19 13:02:46,404, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2019
# 2026-01-19 13:02:46,411, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMPY.
# 2026-01-19 13:02:46,414, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2020
# 2026-01-19 13:02:46,421, 2113979629.py, 4, INFO, Processing ticker: A
# 2026-01-19 13:02:46,430, 2113979629.py, 8, INFO, Processing year 1999 for ticker A.
# 2026-01-19 13:02:46,432, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_1999
# 2026-01-19 13:02:46,439, 2113979629.py, 8, INFO, Processing year 2000 for ticker A.
# 2026-01-19 13:02:46,441, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2000
# 2026-01-19 13:02:46,449, 2113979629.py, 8, INFO, Processing year 2001 for ticker A.
# 2026-01-19 13:02:46,452, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2001
# 2026-01-19 13:02:46,459, 2113979629.py, 8, INFO, Processing year 2002 for ticker A.
# 2026-01-19 13:02:46,461, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2002
# 2026-01-19 13:02:46,469, 2113979629.py, 8, INFO, Processing year 2003 for ticker A.
# 2026-01-19 13:02:46,471, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2003
# 2026-01-19 13:02:46,479, 2113979629.py, 8, INFO, Processing year 2004 for ticker A.
# 2026-01-19 13:02:46,481, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2004
# 2026-01-19 13:02:46,488, 2113979629.py, 8, INFO, Processing year 2005 for ticker A.
# 2026-01-19 13:02:46,490, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2005
# 2026-01-19 13:02:46,498, 2113979629.py, 8, INFO, Processing year 2006 for ticker A.
# 2026-01-19 13:02:46,500, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2006
# 2026-01-19 13:02:46,507, 2113979629.py, 8, INFO, Processing year 2007 for ticker A.
# 2026-01-19 13:02:46,510, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2007
# 2026-01-19 13:02:46,518, 2113979629.py, 8, INFO, Processing year 2008 for ticker A.
# 2026-01-19 13:02:46,520, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2008
# 2026-01-19 13:02:46,528, 2113979629.py, 8, INFO, Processing year 2009 for ticker A.
# 2026-01-19 13:02:46,531, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2009
# 2026-01-19 13:02:46,538, 2113979629.py, 8, INFO, Processing year 2010 for ticker A.
# 2026-01-19 13:02:46,540, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2010
# 2026-01-19 13:02:46,548, 2113979629.py, 8, INFO, Processing year 2011 for ticker A.
# 2026-01-19 13:02:46,551, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2011
# 2026-01-19 13:02:46,558, 2113979629.py, 8, INFO, Processing year 2012 for ticker A.
# 2026-01-19 13:02:46,560, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2012
# 2026-01-19 13:02:46,574, 2113979629.py, 8, INFO, Processing year 2013 for ticker A.
# 2026-01-19 13:02:46,576, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2013
# 2026-01-19 13:02:46,583, 2113979629.py, 8, INFO, Processing year 2014 for ticker A.
# 2026-01-19 13:02:46,585, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2014
# 2026-01-19 13:02:46,593, 2113979629.py, 8, INFO, Processing year 2015 for ticker A.
# 2026-01-19 13:02:46,595, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2015
# 2026-01-19 13:02:46,602, 2113979629.py, 8, INFO, Processing year 2016 for ticker A.
# 2026-01-19 13:02:46,604, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2016
# 2026-01-19 13:02:46,612, 2113979629.py, 8, INFO, Processing year 2017 for ticker A.
# 2026-01-19 13:02:46,615, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2017
# 2026-01-19 13:02:46,623, 2113979629.py, 8, INFO, Processing year 2018 for ticker A.
# 2026-01-19 13:02:46,625, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2018
# 2026-01-19 13:02:46,632, 2113979629.py, 8, INFO, Processing year 2019 for ticker A.
# 2026-01-19 13:02:46,634, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2019
# 2026-01-19 13:02:46,641, 2113979629.py, 8, INFO, Processing year 2020 for ticker A.
# 2026-01-19 13:02:46,643, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2020
# 2026-01-19 13:02:46,650, 2113979629.py, 4, INFO, Processing ticker: WRLSU
# 2026-01-19 13:02:46,658, 2113979629.py, 8, INFO, Processing year 2017 for ticker WRLSU.
# 2026-01-19 13:02:46,661, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2017
# 2026-01-19 13:02:46,668, 2113979629.py, 8, INFO, Processing year 2018 for ticker WRLSU.
# 2026-01-19 13:02:46,670, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2018
# 2026-01-19 13:02:46,678, 2113979629.py, 8, INFO, Processing year 2019 for ticker WRLSU.
# 2026-01-19 13:02:46,680, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2019
# 2026-01-19 13:02:46,688, 2113979629.py, 8, INFO, Processing year 2020 for ticker WRLSU.
# 2026-01-19 13:02:46,691, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2020
# 2026-01-19 13:02:46,699, 2113979629.py, 4, INFO, Processing ticker: PNR
# 2026-01-19 13:02:46,708, 2113979629.py, 8, INFO, Processing year 1973 for ticker PNR.
# 2026-01-19 13:02:46,710, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1973
# 2026-01-19 13:02:46,717, 2113979629.py, 8, INFO, Processing year 1974 for ticker PNR.
# 2026-01-19 13:02:46,719, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1974
# 2026-01-19 13:02:46,727, 2113979629.py, 8, INFO, Processing year 1975 for ticker PNR.
# 2026-01-19 13:02:46,729, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1975
# 2026-01-19 13:02:46,737, 2113979629.py, 8, INFO, Processing year 1976 for ticker PNR.
# 2026-01-19 13:02:46,739, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1976
# 2026-01-19 13:02:46,746, 2113979629.py, 8, INFO, Processing year 1977 for ticker PNR.
# 2026-01-19 13:02:46,749, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1977
# 2026-01-19 13:02:46,756, 2113979629.py, 8, INFO, Processing year 1978 for ticker PNR.
# 2026-01-19 13:02:46,759, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1978
# 2026-01-19 13:02:46,766, 2113979629.py, 8, INFO, Processing year 1979 for ticker PNR.
# 2026-01-19 13:02:46,768, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1979
# 2026-01-19 13:02:46,775, 2113979629.py, 8, INFO, Processing year 1980 for ticker PNR.
# 2026-01-19 13:02:46,777, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1980
# 2026-01-19 13:02:46,784, 2113979629.py, 8, INFO, Processing year 1981 for ticker PNR.
# 2026-01-19 13:02:46,786, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1981
# 2026-01-19 13:02:46,794, 2113979629.py, 8, INFO, Processing year 1982 for ticker PNR.
# 2026-01-19 13:02:46,796, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1982
# 2026-01-19 13:02:46,804, 2113979629.py, 8, INFO, Processing year 1983 for ticker PNR.
# 2026-01-19 13:02:46,807, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1983
# 2026-01-19 13:02:46,814, 2113979629.py, 8, INFO, Processing year 1984 for ticker PNR.
# 2026-01-19 13:02:46,816, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1984
# 2026-01-19 13:02:46,824, 2113979629.py, 8, INFO, Processing year 1985 for ticker PNR.
# 2026-01-19 13:02:46,826, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1985
# 2026-01-19 13:02:46,834, 2113979629.py, 8, INFO, Processing year 1986 for ticker PNR.
# 2026-01-19 13:02:46,836, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1986
# 2026-01-19 13:02:46,843, 2113979629.py, 8, INFO, Processing year 1987 for ticker PNR.
# 2026-01-19 13:02:46,845, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1987
# 2026-01-19 13:02:46,854, 2113979629.py, 8, INFO, Processing year 1988 for ticker PNR.
# 2026-01-19 13:02:46,857, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1988
# 2026-01-19 13:02:46,865, 2113979629.py, 8, INFO, Processing year 1989 for ticker PNR.
# 2026-01-19 13:02:46,867, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1989
# 2026-01-19 13:02:46,875, 2113979629.py, 8, INFO, Processing year 1990 for ticker PNR.
# 2026-01-19 13:02:46,877, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1990
# 2026-01-19 13:02:46,884, 2113979629.py, 8, INFO, Processing year 1991 for ticker PNR.
# 2026-01-19 13:02:46,886, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1991
# 2026-01-19 13:02:46,894, 2113979629.py, 8, INFO, Processing year 1992 for ticker PNR.
# 2026-01-19 13:02:46,896, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1992
# 2026-01-19 13:02:46,904, 2113979629.py, 8, INFO, Processing year 1993 for ticker PNR.
# 2026-01-19 13:02:46,906, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1993
# 2026-01-19 13:02:46,913, 2113979629.py, 8, INFO, Processing year 1994 for ticker PNR.
# 2026-01-19 13:02:46,916, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1994
# 2026-01-19 13:02:46,923, 2113979629.py, 8, INFO, Processing year 1995 for ticker PNR.
# 2026-01-19 13:02:46,926, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1995
# 2026-01-19 13:02:46,933, 2113979629.py, 8, INFO, Processing year 1996 for ticker PNR.
# 2026-01-19 13:02:46,935, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1996
# 2026-01-19 13:02:46,942, 2113979629.py, 8, INFO, Processing year 1997 for ticker PNR.
# 2026-01-19 13:02:46,944, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1997
# 2026-01-19 13:02:46,952, 2113979629.py, 8, INFO, Processing year 1998 for ticker PNR.
# 2026-01-19 13:02:46,954, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1998
# 2026-01-19 13:02:46,961, 2113979629.py, 8, INFO, Processing year 1999 for ticker PNR.
# 2026-01-19 13:02:46,964, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1999
# 2026-01-19 13:02:46,973, 2113979629.py, 8, INFO, Processing year 2000 for ticker PNR.
# 2026-01-19 13:02:46,975, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2000
# 2026-01-19 13:02:46,983, 2113979629.py, 8, INFO, Processing year 2001 for ticker PNR.
# 2026-01-19 13:02:46,985, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2001
# 2026-01-19 13:02:46,993, 2113979629.py, 8, INFO, Processing year 2002 for ticker PNR.
# 2026-01-19 13:02:46,996, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2002
# 2026-01-19 13:02:47,004, 2113979629.py, 8, INFO, Processing year 2003 for ticker PNR.
# 2026-01-19 13:02:47,007, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2003
# 2026-01-19 13:02:47,015, 2113979629.py, 8, INFO, Processing year 2004 for ticker PNR.
# 2026-01-19 13:02:47,017, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2004
# 2026-01-19 13:02:47,025, 2113979629.py, 8, INFO, Processing year 2005 for ticker PNR.
# 2026-01-19 13:02:47,028, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2005
# 2026-01-19 13:02:47,035, 2113979629.py, 8, INFO, Processing year 2006 for ticker PNR.
# 2026-01-19 13:02:47,038, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2006
# ...
# 2026-01-19 13:02:54,911, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2000
# 2026-01-19 13:02:54,919, 2113979629.py, 8, INFO, Processing year 2001 for ticker AMAT.
# 2026-01-19 13:02:54,921, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2001
# 2026-01-19 13:02:54,928, 2113979629.py, 8, INFO, Processing year 2002 for ticker AMAT.
# 2026-01-19 13:02:54,930, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2002
# 2026-01-19 13:02:54,939, 2113979629.py, 8, INFO, Processing year 2003 for ticker AMAT.
# 2026-01-19 13:02:54,941, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2003
# 2026-01-19 13:02:54,949, 2113979629.py, 8, INFO, Processing year 2004 for ticker AMAT.
# 2026-01-19 13:02:54,952, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2004
# 2026-01-19 13:02:54,959, 2113979629.py, 8, INFO, Processing year 2005 for ticker AMAT.
# 2026-01-19 13:02:54,961, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2005
# 2026-01-19 13:02:54,969, 2113979629.py, 8, INFO, Processing year 2006 for ticker AMAT.
# 2026-01-19 13:02:54,972, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2006
# 2026-01-19 13:02:54,979, 2113979629.py, 8, INFO, Processing year 2007 for ticker AMAT.
# 2026-01-19 13:02:54,982, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2007
# 2026-01-19 13:02:54,989, 2113979629.py, 8, INFO, Processing year 2008 for ticker AMAT.
# 2026-01-19 13:02:54,991, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2008
# 2026-01-19 13:02:54,999, 2113979629.py, 8, INFO, Processing year 2009 for ticker AMAT.
# 2026-01-19 13:02:55,002, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2009
# 2026-01-19 13:02:55,015, 2113979629.py, 8, INFO, Processing year 2010 for ticker AMAT.
# 2026-01-19 13:02:55,017, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2010
# 2026-01-19 13:02:55,025, 2113979629.py, 8, INFO, Processing year 2011 for ticker AMAT.
# 2026-01-19 13:02:55,027, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2011
# 2026-01-19 13:02:55,034, 2113979629.py, 8, INFO, Processing year 2012 for ticker AMAT.
# 2026-01-19 13:02:55,036, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2012
# 2026-01-19 13:02:55,044, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMAT.
# 2026-01-19 13:02:55,047, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2013
# 2026-01-19 13:02:55,054, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMAT.
# 2026-01-19 13:02:55,056, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2014
# 2026-01-19 13:02:55,064, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMAT.
# 2026-01-19 13:02:55,066, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2015
# 2026-01-19 13:02:55,074, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMAT.
# 2026-01-19 13:02:55,076, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2016
# 2026-01-19 13:02:55,083, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMAT.
# 2026-01-19 13:02:55,085, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2017
# 2026-01-19 13:02:55,092, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMAT.
# 2026-01-19 13:02:55,094, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2018
# 2026-01-19 13:02:55,101, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMAT.
# 2026-01-19 13:02:55,103, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2019
# 2026-01-19 13:02:55,111, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMAT.
# 2026-01-19 13:02:55,113, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2020
# 2026-01-19 13:02:55,121, 2113979629.py, 4, INFO, Processing ticker: PSB
# 2026-01-19 13:02:55,130, 2113979629.py, 8, INFO, Processing year 1991 for ticker PSB.
# 2026-01-19 13:02:55,133, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1991
# 2026-01-19 13:02:55,139, 2113979629.py, 8, INFO, Processing year 1992 for ticker PSB.
# 2026-01-19 13:02:55,142, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1992
# 2026-01-19 13:02:55,150, 2113979629.py, 8, INFO, Processing year 1993 for ticker PSB.
# 2026-01-19 13:02:55,152, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1993
# 2026-01-19 13:02:55,173, 2113979629.py, 8, INFO, Processing year 1994 for ticker PSB.
# 2026-01-19 13:02:55,194, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1994
# 2026-01-19 13:02:55,208, 2113979629.py, 8, INFO, Processing year 1995 for ticker PSB.
# 2026-01-19 13:02:55,211, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1995
# 2026-01-19 13:02:55,218, 2113979629.py, 8, INFO, Processing year 1996 for ticker PSB.
# 2026-01-19 13:02:55,220, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1996
# 2026-01-19 13:02:55,228, 2113979629.py, 8, INFO, Processing year 1997 for ticker PSB.
# 2026-01-19 13:02:55,231, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1997
# 2026-01-19 13:02:55,239, 2113979629.py, 8, INFO, Processing year 1998 for ticker PSB.
# 2026-01-19 13:02:55,241, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1998
# 2026-01-19 13:02:55,248, 2113979629.py, 8, INFO, Processing year 1999 for ticker PSB.
# 2026-01-19 13:02:55,250, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1999
# 2026-01-19 13:02:55,257, 2113979629.py, 8, INFO, Processing year 2000 for ticker PSB.
# 2026-01-19 13:02:55,259, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2000
# 2026-01-19 13:02:55,266, 2113979629.py, 8, INFO, Processing year 2001 for ticker PSB.
# 2026-01-19 13:02:55,268, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2001
# 2026-01-19 13:02:55,275, 2113979629.py, 8, INFO, Processing year 2002 for ticker PSB.
# 2026-01-19 13:02:55,278, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2002
# 2026-01-19 13:02:55,285, 2113979629.py, 8, INFO, Processing year 2003 for ticker PSB.
# 2026-01-19 13:02:55,287, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2003
# 2026-01-19 13:02:55,294, 2113979629.py, 8, INFO, Processing year 2004 for ticker PSB.
# 2026-01-19 13:02:55,296, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2004
# 2026-01-19 13:02:55,304, 2113979629.py, 8, INFO, Processing year 2005 for ticker PSB.
# 2026-01-19 13:02:55,306, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2005
# 2026-01-19 13:02:55,319, 2113979629.py, 8, INFO, Processing year 2006 for ticker PSB.
# 2026-01-19 13:02:55,321, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2006
# 2026-01-19 13:02:55,328, 2113979629.py, 8, INFO, Processing year 2007 for ticker PSB.
# 2026-01-19 13:02:55,330, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2007
# 2026-01-19 13:02:55,337, 2113979629.py, 8, INFO, Processing year 2008 for ticker PSB.
# 2026-01-19 13:02:55,339, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2008
# 2026-01-19 13:02:55,347, 2113979629.py, 8, INFO, Processing year 2009 for ticker PSB.
# 2026-01-19 13:02:55,349, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2009
# 2026-01-19 13:02:55,356, 2113979629.py, 8, INFO, Processing year 2010 for ticker PSB.
# 2026-01-19 13:02:55,358, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2010
# 2026-01-19 13:02:55,365, 2113979629.py, 8, INFO, Processing year 2011 for ticker PSB.
# 2026-01-19 13:02:55,367, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2011
# 2026-01-19 13:02:55,375, 2113979629.py, 8, INFO, Processing year 2012 for ticker PSB.
# 2026-01-19 13:02:55,377, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2012
# 2026-01-19 13:02:55,384, 2113979629.py, 8, INFO, Processing year 2013 for ticker PSB.
# 2026-01-19 13:02:55,386, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2013
# 2026-01-19 13:02:55,394, 2113979629.py, 8, INFO, Processing year 2014 for ticker PSB.
# 2026-01-19 13:02:55,396, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2014
# 2026-01-19 13:02:55,403, 2113979629.py, 8, INFO, Processing year 2015 for ticker PSB.
# 2026-01-19 13:02:55,405, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2015
# 2026-01-19 13:02:55,421, 2113979629.py, 8, INFO, Processing year 2016 for ticker PSB.
# 2026-01-19 13:02:55,441, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2016
# 2026-01-19 13:02:55,454, 2113979629.py, 8, INFO, Processing year 2017 for ticker PSB.
# 2026-01-19 13:02:55,456, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2017
# 2026-01-19 13:02:55,463, 2113979629.py, 8, INFO, Processing year 2018 for ticker PSB.
# 2026-01-19 13:02:55,466, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2018
# 2026-01-19 13:02:55,475, 2113979629.py, 8, INFO, Processing year 2019 for ticker PSB.
# 2026-01-19 13:02:55,477, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2019
# 2026-01-19 13:02:55,485, 2113979629.py, 8, INFO, Processing year 2020 for ticker PSB.
# 2026-01-19 13:02:55,487, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2020
# 2026-01-19 13:02:55,505, 2113979629.py, 4, INFO, Processing ticker: CTSO
# 2026-01-19 13:02:55,514, 2113979629.py, 8, INFO, Processing year 2006 for ticker CTSO.
# 2026-01-19 13:02:55,517, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2006
# 2026-01-19 13:02:55,526, 2113979629.py, 8, INFO, Processing year 2007 for ticker CTSO.
# 2026-01-19 13:02:55,530, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2007
# 2026-01-19 13:02:55,538, 2113979629.py, 8, INFO, Processing year 2008 for ticker CTSO.
# 2026-01-19 13:02:55,540, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2008
# 2026-01-19 13:02:55,548, 2113979629.py, 8, INFO, Processing year 2009 for ticker CTSO.
# 2026-01-19 13:02:55,550, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2009
# 2026-01-19 13:02:55,558, 2113979629.py, 8, INFO, Processing year 2010 for ticker CTSO.
# 2026-01-19 13:02:55,560, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2010
# 2026-01-19 13:02:55,567, 2113979629.py, 8, INFO, Processing year 2011 for ticker CTSO.
# 2026-01-19 13:02:55,569, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2011
# 2026-01-19 13:02:55,576, 2113979629.py, 8, INFO, Processing year 2012 for ticker CTSO.
# 2026-01-19 13:02:55,578, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2012
# 2026-01-19 13:02:55,586, 2113979629.py, 8, INFO, Processing year 2013 for ticker CTSO.
# 2026-01-19 13:02:55,589, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2013
# 2026-01-19 13:02:55,596, 2113979629.py, 8, INFO, Processing year 2014 for ticker CTSO.
# 2026-01-19 13:02:55,598, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2014
# 2026-01-19 13:02:55,605, 2113979629.py, 8, INFO, Processing year 2015 for ticker CTSO.
# 2026-01-19 13:02:55,607, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2015
# 2026-01-19 13:02:55,614, 2113979629.py, 8, INFO, Processing year 2016 for ticker CTSO.
# 2026-01-19 13:02:55,616, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2016
# 2026-01-19 13:02:55,630, 2113979629.py, 8, INFO, Processing year 2017 for ticker CTSO.
# 2026-01-19 13:02:55,632, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2017
# 2026-01-19 13:02:55,640, 2113979629.py, 8, INFO, Processing year 2018 for ticker CTSO.
# 2026-01-19 13:02:55,642, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2018
# 2026-01-19 13:02:55,650, 2113979629.py, 8, INFO, Processing year 2019 for ticker CTSO.
# 2026-01-19 13:02:55,652, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2019
# 2026-01-19 13:02:55,659, 2113979629.py, 8, INFO, Processing year 2020 for ticker CTSO.
# 2026-01-19 13:02:55,661, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2020
# 2026-01-19 13:02:55,668, 2113979629.py, 4, INFO, Processing ticker: UEC
# 2026-01-19 13:02:55,677, 2113979629.py, 8, INFO, Processing year 2007 for ticker UEC.
# 2026-01-19 13:02:55,680, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2007
# 2026-01-19 13:02:55,687, 2113979629.py, 8, INFO, Processing year 2008 for ticker UEC.
# 2026-01-19 13:02:55,690, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2008
# 2026-01-19 13:02:55,697, 2113979629.py, 8, INFO, Processing year 2009 for ticker UEC.
# 2026-01-19 13:02:55,700, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2009
# 2026-01-19 13:02:55,707, 2113979629.py, 8, INFO, Processing year 2010 for ticker UEC.
# 2026-01-19 13:02:55,710, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2010
# 2026-01-19 13:02:55,717, 2113979629.py, 8, INFO, Processing year 2011 for ticker UEC.
# 2026-01-19 13:02:55,719, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2011
# 2026-01-19 13:02:55,727, 2113979629.py, 8, INFO, Processing year 2012 for ticker UEC.
# 2026-01-19 13:02:55,729, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2012
# 2026-01-19 13:02:55,737, 2113979629.py, 8, INFO, Processing year 2013 for ticker UEC.
# 2026-01-19 13:02:55,739, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2013
# 2026-01-19 13:02:55,747, 2113979629.py, 8, INFO, Processing year 2014 for ticker UEC.
# 2026-01-19 13:02:55,749, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2014
# 2026-01-19 13:02:55,756, 2113979629.py, 8, INFO, Processing year 2015 for ticker UEC.
# 2026-01-19 13:02:55,759, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2015
# 2026-01-19 13:02:55,765, 2113979629.py, 8, INFO, Processing year 2016 for ticker UEC.
# 2026-01-19 13:02:55,767, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2016
# 2026-01-19 13:02:55,781, 2113979629.py, 8, INFO, Processing year 2017 for ticker UEC.
# 2026-01-19 13:02:55,784, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2017
# 2026-01-19 13:02:55,791, 2113979629.py, 8, INFO, Processing year 2018 for ticker UEC.
# 2026-01-19 13:02:55,794, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2018
# 2026-01-19 13:02:55,802, 2113979629.py, 8, INFO, Processing year 2019 for ticker UEC.
# 2026-01-19 13:02:55,804, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2019
# 2026-01-19 13:02:55,811, 2113979629.py, 8, INFO, Processing year 2020 for ticker UEC.
# 2026-01-19 13:02:55,814, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2020

# %% [markdown]
# Why would we want to store data this way?
#
# + Data files are easier to maintain. We do not update old data, only recent data or the most recent "delta".
# + Parquet files, as long as they maintain a consistent schema, can all be read jointly.

# %% [markdown]
# # Load, Transform, and Save
#
# In this section, we will load the Parquet files we generated, transform the data, and save the resulting dataset.

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to obtain the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
_logs.info(f'Found {len(parquet_files)} parquet files for reading back into Dask.')

dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# 2026-01-19 13:03:05,298, 174194153.py, 4, INFO, Found 2010 parquet files for reading back into Dask.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work similarly to Pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.
#
# In the code below, the following operation occurs:
#
# + Start with a Dask dataframe, `dd_px`.
# + Group the rows of this dataframe by the variable `ticker`, i.e., each group will contain the observations that pertain only to one ticker at a time. The `group_key` parameter controls whether an index entry is added with the value of the grouping variable (`ticker` in this case); if we made `group_keys=True`, we would have a duplicate `ticker` column.
# + For each group defined by a `ticker`, `apply()` the following calculation:
#
#     - Sort the values by `Date` in ascending order.
#     - Assign a new variable called `Close_lag_1` by shifting the position of the closing price (`Close`) by one position.
#     - Define the schema of the resulting dataframe. If we omit this specification, we would get a warning; however, the simplicity of the calculation ensures that Dask can determine the resulting schema.

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# A               datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32
# ACB                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: setindex, 2 expressions
# Expr=SetIndex(frame=ReadParquetFSSpec(06d52dc), _other='ticker', options={})

# %%
dd_shift = (
    dd_px
        .groupby('ticker', group_keys=False)
        .apply(
            lambda x: x.sort_values('Date', ascending = True)
                       .assign(Close_lag_1 = x['Close'].shift(1)), 
            meta = pd.DataFrame(data ={'Date': 'datetime64[ns]',
                    'Open': 'f8',
                    'High': 'f8',
                    'Low': 'f8',
                    'Close': 'f8',
                    'Adj Close': 'f8',
                    'Volume': 'i8',
                    'source': 'object',
                    'Year': 'int32',
                    'Close_lag_1': 'f8'},
                    index = pd.Index([], dtype=pd.StringDtype(), name='ticker'))
    ))

# %% [markdown]
# Finally, using the dataframe that we created above, we can now `assign` the `Returns` variable to the entire dataset.

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# Question: How do we know that we are not (erroneously) combining the last price of a ticker with the first price of the next ticker?

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# A               object  object  object  object  object    object  object  object  object      object  object
# ACB                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(06d52dc), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x14e509ee0>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until the computation is required.
# + To trigger an execution in dask use `.compute()` or execute a command that requires the actual values (for example, write to Parquet or SQL).

# %%
dd_rets.compute()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# ticker
# A      1999-11-18  32.546494  35.765381  28.612303  31.473534  27.068665
# A      1999-11-19  30.713520  30.758226  28.478184  28.880543  24.838577
# A      1999-11-22  29.551144  31.473534  28.657009  31.473534  27.068665
# A      1999-11-23  30.400572  31.205294  28.612303  28.612303  24.607880
# A      1999-11-24  28.701717  29.998211  28.612303  29.372318  25.261524
# ...           ...        ...        ...        ...        ...        ...
# ZEUS   2020-03-26   9.610000   9.940000   9.260000   9.590000   9.590000
# ZEUS   2020-03-27   9.330000   9.330000   8.700000   8.700000   8.700000
# ZEUS   2020-03-30   8.810000   9.760000   8.700000   9.680000   9.680000
# ZEUS   2020-03-31   9.640000  10.470000   9.590000  10.350000  10.350000
# ZEUS   2020-04-01  10.140000  10.340000   9.310000   9.470000   9.470000
#
#             Volume    source  Year  Close_lag_1   Returns
# ticker
# A       62546300.0     A.csv  1999          NaN       NaN
# A       15234100.0     A.csv  1999    39.360001 -0.266246
# A        6577800.0     A.csv  1999    39.790001 -0.209009
# A        5975600.0     A.csv  1999    38.750000 -0.261618
# A        4843200.0     A.csv  1999    38.919998 -0.245316
# ...            ...       ...   ...          ...       ...
# ZEUS       60500.0  ZEUS.csv  2020     6.870000  0.395924
# ZEUS       52900.0  ZEUS.csv  2020     6.990000  0.244635
# ZEUS       73700.0  ZEUS.csv  2020     7.630000  0.268676
# ZEUS       68900.0  ZEUS.csv  2020     8.200000  0.262195
# ZEUS       34000.0  ZEUS.csv  2020     8.500000  0.114118
#
# [230273 rows x 11 columns]

# %% [markdown]
# ## Save
#
# With our transformed data, we can now save the new feature to a Parquet file. We will need to answer the following questions depending on our context, setup, and available resources:
#
# + Should we keep the same namespace?
# + Should we save all columns?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# A               object  object  object  object  object    object  object  object  object      object  object
# ACB                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(06d52dc), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x14e509ee0>, args=(), kwargs={})))

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, 
                   overwrite = True, 
                   schema={
                       'Date': 'timestamp[ns]',
                       'Open': 'float64',
                       'High': 'float64',
                       'Low': 'float64',
                       'Close': 'float64',
                       'Adj Close': 'float64',
                       'Volume': 'int64',
                       'source': 'string',
                       'Year': 'int32',
                       'Close_lag_1': 'float64',
                       'Returns': 'float64',
                       'ticker': 'large_string'
                   })

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
